# %% [markdown]
# Due to the great influence of random factors, the results from a single running may be significantly different. Please run it several times and choose the best result.

# %%
run training_example_of_koniq  # first time training
# Out:
# Test Epoch:-1 [(0%)]	 Loss: 10.3180  Loss1: 10.3180  Loss2: 9.6279
# Test : Loss:10.3039
# ALL Pearson: -0.02000140900298917
# ALL Spearman: -0.04204021056543788
# 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# 0.7137703895568848
# Train Epoch: 0 [(0%)]	Loss: 9.9535Loss1: 9.9535Loss2: 9.5058
# 21.734562873840332
# Test Epoch:0 [(0%)]	 Loss: 1.0391  Loss1: 1.0391  Loss2: 10.0142
# Test : Loss:0.9841
# ALL Pearson: -0.05365529475150335
# ALL Spearman: -0.06597699717540416
# time: 26.546020030975342
# 0.01
# 0.7187676429748535
# Train Epoch: 1 [(0%)]	Loss: 2.4416Loss1: 2.4416Loss2: 9.3068
# 22.68031144142151
# Test Epoch:1 [(0%)]	 Loss: 0.5780  Loss1: 0.5780  Loss2: 10.0373
# Test : Loss:0.5416
# ALL Pearson: 0.05391518177699513
# ALL Spearman: 0.0364289836454422
# time: 27.511122941970825
# 0.01
# 0.7492969036102295
# ...

# %%
run training_example_of_koniq # second time training
# Out:
# Test Epoch:-1 [(0%)]	 Loss: 10.3207  Loss1: 10.3207  Loss2: 10.3207
# Test : Loss:10.3067
# ALL Pearson: nan
# ALL Spearman: nan
# 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# 0.7367665767669678
# Train Epoch: 0 [(0%)]	Loss: 10.3124Loss1: 10.3124Loss2: 10.3042
# 22.11508321762085
# Test Epoch:0 [(0%)]	 Loss: 10.3207  Loss1: 10.3207  Loss2: 10.3207
# Test : Loss:10.3067
# ALL Pearson: nan
# ALL Spearman: nan
# time: 27.053256034851074
# 0.01
# 0.6527903079986572
# Train Epoch: 1 [(0%)]	Loss: 10.2922Loss1: 10.2922Loss2: 10.2735
# 21.613658905029297
# Test Epoch:1 [(0%)]	 Loss: 2.7147  Loss1: 2.7147  Loss2: 10.3207
# Test : Loss:2.6441
# ALL Pearson: -0.014669104984874747
# ALL Spearman: -0.02417827330977077
# time: 26.39956307411194
# 0.01
# 0.6573271751403809
# Train Epoch: 2 [(0%)]	Loss: 3.8537Loss1: 3.8537Loss2: 10.3101
# ...

# %%
run training_example_of_koniq # third time training
# Out:
# Test Epoch:-1 [(0%)]	 Loss: 10.3207  Loss1: 10.3207  Loss2: 7.4081
# Test : Loss:10.3065
# ALL Pearson: 0.014093676138763328
# ALL Spearman: 0.014923510574778294
# 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# 0.7478117942810059
# Train Epoch: 0 [(0%)]	Loss: 10.0800Loss1: 10.0800Loss2: 7.5557
# 22.824485540390015
# Test Epoch:0 [(0%)]	 Loss: 1.0751  Loss1: 1.0751  Loss2: 8.6949
# Test : Loss:1.0124
# ALL Pearson: -0.008781941684687423
# ALL Spearman: -0.017011775108122136
# time: 27.698712825775146
# 0.01
# 0.7947449684143066
# Train Epoch: 1 [(0%)]	Loss: 1.8596Loss1: 1.8596Loss2: 8.7037
# 23.7225239276886
# Test Epoch:1 [(0%)]	 Loss: 0.4813  Loss1: 0.4813  Loss2: 8.4561
# Test : Loss:0.4535
# ALL Pearson: 0.22431183029094903
# ALL Spearman: 0.20601620993589886
# time: 28.84107255935669
# 0.01
# 0.7127716541290283
# ...
