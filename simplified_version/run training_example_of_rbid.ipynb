# %%
run training_example_of_rbid #fix bn
# Out:
# Split: 0
# Test Epoch: -1 ALL Pearson: 0.17190620681104488
# Test Epoch: -1 ALL Spearman: 0.21820618729890917
# 0.01
# C:\ProgramData\Anaconda3\lib\site-packages\torch\cuda\nccl.py:16: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn('PyTorch is not compiled with NCCL support')
# Train Epoch: 0 ALL Pearson: -0.03170143886566627
# Train Epoch: 0 ALL Spearman: -0.029656070710380494
# 1.5165133476257324
# Test Epoch: 0 ALL Pearson: 0.05210662933995498
# Test Epoch: 0 ALL Spearman: 0.07021804589548206
# time: 1.8853950500488281
# 0.01
# Train Epoch: 1 ALL Pearson: -0.11192418771047954
# Train Epoch: 1 ALL Spearman: -0.08635486262130568
# 1.372558355331421
# Test Epoch: 1 ALL Pearson: 0.03159344519340501
# Test Epoch: 1 ALL Spearman: 0.022018194500746845
# time: 1.7274467945098877
# 0.01
# Train Epoch: 2 ALL Pearson: 0.015856056481116695
# Train Epoch: 2 ALL Spearman: 0.0012980784300930892
# 1.3385694026947021
# Test Epoch: 2 ALL Pearson: 0.07684732590688585
# ...
